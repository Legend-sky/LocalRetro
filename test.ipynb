# %%
def modify_list(lst):
    lst.append(4)  # 修改 lst 指向的对象

a = [1, 2, 3]
modify_list(a)
print(a)  # 输出 [1, 2, 3, 4]
# Out:
# [1, 2, 3, 4]

# %%
def reassign_list(lst):
    lst = [4, 5, 6]  # 重新赋值，lst 指向新的列表对象

a = [1, 2, 3]
reassign_list(a)
print(a)  # 输出 [1, 2, 3]，没有变化
# Out:
# [1, 2, 3]

# %%
def modify_string(s):
    s = s + " world"  # 创建了一个新的字符串对象

a = "hello"
modify_string(a)
print(a)  # 输出 "hello"，没有变化
# Out:
# hello

# %%
import numpy as np
from rdkit import Chem
from rdkit.Chem import Draw

smiles = ['NC(=O)c1cc([N+](=O)[O-])ncc1Cl','CO[C:1](=[O:2])[c:3]1[cH:4][cH:5][n:6][c:7]([N+:8](=[O:9])[O-:10])[cH:11]1.[NH3:12]']
img = Draw.MolsToGridImage([Chem.MolFromSmiles(x) for x in smiles], molsPerRow=3, subImgSize=(300, 300))
display(img)
